# %%
# Install and Load Necessary Packages

import pandas as pd
from numpy import nan as NA
import matplotlib.pyplot as plt
import string
import numpy as np 

import plotly.plotly as py

# %% [markdown]
# # Import Military Spending Data for 10 countries (2013-2017)

# %%
# Read Files Csv
MilitaryExpenditure_WorldBank = pd.read_csv("militaryexpenditureWorldBank1.csv")
MilitaryExpenditure_WorldBank.head(5)

# %%
# Type of our dataset
type(MilitaryExpenditure_WorldBank) # shows that we are dealing with a data frame

# View data type of each column 
#print(MilitaryExpenditure_WorldBank.dtypes) # shows us that it is a float object

# View Rows
#MilitaryExpenditure_WorldBank.index # gives us information about the rows by using index. starts at 0 and stops at 268

# %%
#Dimension of Military Spending data frame
# looking at the shape of the Military Expenditure data from World Bank
MilitaryExpenditure_WorldBank.shape # 268 rows and 62 columns

# %%
MilitaryExpenditure_WorldBank.describe() # max, min for each year

# %%
MilitaryExpenditure_WorldBank.info() # Information on our data frame

# %%
#MilitaryExpenditure_WorldBank.columns # names of columns
#MilitaryExpenditure_WorldBank.index # length of index

# %% [markdown]
# # Data Cleaning (Military Spending Data)
# 1) Remove empty space in the Military Expendenture_ WorldBank data set using python
# 2) Remove Columns and Rows that dont have any useful information for our analysis.
# 3) Rename Column Headers
# 4) Lengthen numers into float

# %%
# Remove Columns
MilitaryExpenditure_WorldBank.drop(MilitaryExpenditure_WorldBank.iloc[:,2:57], axis=1, inplace=True)
MilitaryExpenditure_WorldBank.head(5) # now our columns start from 2013 but we need to delete rows as well

# %%
# Remove Rows in excel because of the header
MilitaryExpenditure_WorldBank.drop([0,1,2,3], axis=0, inplace=True)
MilitaryExpenditure_WorldBank.head(5)

# %%
# replace column name
MilitaryExpenditure_WorldBank.columns=['Country Name','Country Code','2013','2014','2015','2016','2017']
MilitaryExpenditure_WorldBank.head(5)

# %%
MilitaryExpenditure_WorldBank.drop(['Country Code'], axis=1, inplace=True) # drop country code
MilitaryExpenditure_WorldBank.head(5)

# %%
#Rename existing data column Country Name to Country
MilitaryExpenditure_WorldBank.rename(columns={'Country Name': 'Country'}, inplace=True)
MilitaryExpenditure_WorldBank.head()

# %% [markdown]
# ### Missing Values?

# %%
#MilitaryExpenditure_WorldBank.isnull().values.any() # any values at all missing/NAN in my data frame? if it's true go down
#MilitaryExpenditure_WorldBank.isnull() # True or False showsing whats missing
MilitaryExpenditure_WorldBank.isnull().sum() # sum of missing values in each year

# %%
#Visualize missing data
MilitaryExpenditure_WorldBank.isnull().sum().plot(kind='bar',legend=True, figsize=(12,6))

# %% [markdown]
# # Subset The Military Spending of 10 Countries

# %%
## Select Top 10 Countries for Military Spending
MilitaryExpenditure_WorldBank.set_index("Country", inplace=True) # set the index of data frame to country

# %%
TenCountriesSpending = MilitaryExpenditure_WorldBank.loc[['United States', 'China', 'Russian Federation', 'Germany', 'United Kingdom', 'France', 'Italy', 'Iran, Islamic Rep.', 'Israel','Saudi Arabia']]
TenCountriesSpending.head(10)

# %%
TenCountriesSpending.T

# %% [markdown]
# ### Missing Values?

# %%
TenCountriesSpending.isnull() # shows us they are all 'False' or lacking missing values

# %%
TenCountriesMilitarySpendingTransposed = TenCountriesSpending.transpose()
TenCountriesMilitarySpendingTransposed.head()

# %%
TenCountriesSpending.head(10).to_csv('Top10Countries.csv') # save to file the clean version

# %% [markdown]
# ### Read Files Csv

# %%
# Read Files Csv
TenCountriesSpending2 = pd.read_csv("Top10Countries.csv")
TenCountriesSpending2.head(10)
MilitarySpending= TenCountriesSpending2.head(10).T.drop('Country')
# replace column name
MilitarySpending.columns=['United States','China','Russian Federation','Germany','United Kingdom','France','Italy','Iran, Islamic Rep.','Israel','Saudi Arabia']
MilitarySpending
# Out:
#         United States            China Russian Federation         Germany  \
# 2013 639704000000.000 179880000000.000    88352896464.000 45930540563.000
# 2014 609914000000.000 200772000000.000    84696504653.000 46102673010.000
# 2015 596105000000.000 214093000000.000    66418708184.000 39812576245.000
# 2016 600106000000.000 216031000000.000    69245309461.000 41579494874.000
# 2017 609758000000.000 228231000000.000    66334987911.000 44329281681.000
#
#       United Kingdom          France           Italy Iran, Islamic Rep.  \
# 2013 56861759588.000 62417099178.000 33891913925.000    11997186984.000
# 2014 59182858554.000 63613569143.000 31572443580.000     9901105170.000
# 2015 53862185493.000 55342131529.000 25294630143.000    10588769671.000
# 2016 48118943518.000 57358414419.000 28205844821.000    12263957415.000
# 2017 47193096612.000 57770123196.000 29236394240.000    14548050128.000
#
#               Israel    Saudi Arabia
# 2013 17302223635.000 67020000000.000
# ...

# %%
MilitarySpending.plot(kind = 'bar',figsize=(17,10),fontsize = 10)
plt.ticklabel_format(style='plain',axis='y')

# %% [markdown]
# # Import GDP Data for 10 countries (2013-2017)

# %%
# Read Files Csv
GDP_WorldBank = pd.read_csv("GDP World Bank.csv")
GDP_WorldBank.head(10)

# %%
#GDP_WorldBank.info()
#GDP_WorldBank.index 
#GDP_WorldBank.columns # gives us information about the columns in our dataset

# %% [markdown]
# # Data Cleaning (GDP Data)
# 1) Remove empty space in the GDP data set using python
# 2) Remove Columns and Rows that dont have any useful information for our analysis.
# 3) Rename Column Headers
# 4) Lengthen numers into float

# %%
# Remove GDP Columns 
GDP_WorldBank.drop(GDP_WorldBank.iloc[:,2:57], axis=1, inplace=True)
GDP_WorldBank.head(5) # now our columns start from Country Code then 2013-2017 but we need to delete rows as well

# %%
# Remove Rows in excel because of the header
GDP_WorldBank.drop([0,1,2,3], axis=0, inplace=True)
GDP_WorldBank.head()

# %%
# replace column name
GDP_WorldBank.columns=['Country Name','Country Code','2013','2014','2015','2016','2017']
GDP_WorldBank.head(5)

# %%
GDP_WorldBank.drop(['Country Code'], axis=1, inplace=True) # drop country code

#Rename existing data column Country Name to Country
GDP_WorldBank.rename(columns={'Country Name': 'Country'}, inplace=True)
GDP_WorldBank.head(10)

# %%
######## lengthens numbers 
pd.set_option('display.float_format', lambda x: '%.3f' % x)
GDP_WorldBank.head()

# %% [markdown]
# ### Missing Values?

# %%
GDP_WorldBank.isnull().values.any() #check whether any of the values in the GDP dataframe contain missing value/NAN

# %%
GDP_WorldBank.isnull().sum().sum() # total sum of missing values

# %%
GDP_WorldBank.isnull().sum() # sum of missing values in each column

# %%
GDP_WorldBank['2017'].isnull().sum() # confirming that 2017 has the highes numbers of missing values

# %%
# We can also visualize our missing values
GDP_WorldBank.isnull().sum().plot(kind='bar',legend=True, figsize=(12,6))

# %% [markdown]
# # Subset GDP for 10 Countries

# %%
GDP_TenCountries=GDP_WorldBank.set_index("Country", inplace=True) # set the index of data frame to country
GDP_TenCountries

# %%
## Select Top 10 Countries for Military Spending
GDP_TenCountries = GDP_WorldBank.loc[['United States', 'China', 'Russian Federation', 'Germany', 'United Kingdom', 'France', 'Italy', 'Iran, Islamic Rep.', 'Israel','Saudi Arabia']]
GDP_TenCountries.head(10)

# %%
GDP_TenCountries.T

# %%
GDP_TenCountries.isnull().values.any() #Shows we no longer have missing values in the new subset data frame GDP_TenCountries

# %%
#GDP_TenCountries.head(10).to_csv('GDP10Countries.csv') # save to file the clean version

# %%
# Read Files Csv
GDP_TenCountries = pd.read_csv("GDP10Countries.csv")
GDP_TenCountries.head(10)
GDP= GDP_TenCountries.head(10).T.drop('Country')
# replace column name
GDP.columns=['United States','China','Russian Federation','Germany','United Kingdom','France','Italy','Iran, Islamic Rep.','Israel','Saudi Arabia']
GDP
# Out:
#      United States        China Russian Federation      Germany  \
# 2013   1.66915e+13  9.60722e+12        2.29713e+12  3.75251e+12
# 2014   1.74276e+13  1.04824e+13        2.06366e+12  3.89061e+12
# 2015   1.81207e+13  1.10647e+13         1.3684e+12  3.37561e+12
# 2016   1.86245e+13   1.1191e+13        1.28473e+12   3.4778e+12
# 2017   1.93906e+13  1.22377e+13        1.57752e+12  3.67744e+12
#
#      United Kingdom       France        Italy Iran, Islamic Rep.       Israel  \
# 2013    2.73982e+12  2.81108e+12  2.13049e+12        4.67415e+11  2.92489e+11
# 2014    3.02283e+12  2.85217e+12  2.15173e+12        4.34475e+11  3.08417e+11
# 2015    2.88557e+12  2.43821e+12  1.83287e+12        3.85874e+11  2.99094e+11
# 2016    2.65085e+12  2.46513e+12  1.85938e+12        4.18977e+11  3.17748e+11
# 2017    2.62243e+12   2.5825e+12   1.9348e+12        4.39514e+11  3.50851e+11
#
#      Saudi Arabia
# 2013  7.46647e+11
# 2014   7.5635e+11
# 2015   6.5427e+11
# 2016  6.44936e+11
# ...

# %%
GDP.plot(kind = 'bar',figsize=(10,8),fontsize = 10)
plt.ticklabel_format(style='plain',axis='y')

# %% [markdown]
# # 1) Compare the data to that country’s GDP

# %%
#2)Compare the data to that country’s GDP
Ratio= (MilitarySpending/GDP)*100 # Military expenditure as percentage of gross domestic product (GDP)

# %%
Ratio
#porportion of military expenditure in gdp. for example, from the gross domestic product
#of saudi arabia extracted in year 2015, close to 14% was used for  military expenditure which is higher
#than any countries. accross 2013-2017 saudi is noticebly spending more than others
# Out:
#      United States    China Russian Federation  Germany United Kingdom  \
# 2013       3.83251  1.87234            3.84623    1.224        2.07538
# 2014        3.4997  1.91532            4.10419  1.18497        1.95786
# 2015       3.28964  1.93492            4.85375  1.17942         1.8666
# 2016       3.22213   1.9304            5.38987  1.19557        1.81523
# 2017       3.14461  1.86498            4.20502  1.20544        1.79959
#
#        France    Italy Iran, Islamic Rep.   Israel Saudi Arabia
# 2013   2.2204   1.5908            2.56671  5.91551      8.97613
# 2014  2.23036  1.46731            2.27887  5.99225      10.6779
# 2015  2.26979  1.38006             2.7441  5.67154      13.3257
# 2016  2.32679  1.51695            2.92712  4.65236      9.87273
# 2017  2.23698  1.51108            3.31003  4.69972      10.1507

# %%
Ratio.plot(kind = 'bar',figsize=(10,8),fontsize = 10)
plt.ticklabel_format(style='plain',axis='y') # Military expenditure as percentage of gross domestic product (GDP)

# %%
# An increase in military expenditure can be interpreted as having more power in comparison to other countries.

# %% [markdown]
# # 2) •	Compare the data to the overall military spending of the all 10 countries

# %%
#3) •	Compare the data to the overall military spending of the all 10 countries
MilitarySpending_melt = pd.melt(frame=TenCountriesSpending2, id_vars='Country')

# Rename the columns
MilitarySpending_melt.columns = ['Country', 'Year', 'Spending']

# Print 
print(MilitarySpending_melt.head(1000))
# Out:
#                Country  Year         Spending
# 0        United States  2013 639704000000.000
# 1                China  2013 179880000000.000
# 2   Russian Federation  2013  88352896464.000
# 3              Germany  2013  45930540563.000
# 4       United Kingdom  2013  56861759588.000
# 5               France  2013  62417099178.000
# 6                Italy  2013  33891913925.000
# 7   Iran, Islamic Rep.  2013  11997186984.000
# 8               Israel  2013  17302223635.000
# 9         Saudi Arabia  2013  67020000000.000
# 10       United States  2014 609914000000.000
# 11               China  2014 200772000000.000
# 12  Russian Federation  2014  84696504653.000
# 13             Germany  2014  46102673010.000
# 14      United Kingdom  2014  59182858554.000
# 15              France  2014  63613569143.000
# 16               Italy  2014  31572443580.000
# 17  Iran, Islamic Rep.  2014   9901105170.000
# 18              Israel  2014  18481108494.000
# ...

# %%
# Key findings

# For example, in 2013, USA had a high military spending total of $639,704,000,000 but juding by 2017 military spending
# $609,758,000,000 I see there was a $29,946,000,000 decline in the past five year in military spending.

#On the other hand, in 2013, Saudi Arabia had a military spending total of $67,020,000,000 but increased
#slightly in the past five years to 69,413,333,333

# China in 2013 spent $179,880,000,000 and in 2017 spent $228,231,000,000 which increased it's spending
# by a total of $48,351,000,000 within the past five years

# %%
# Let's look at 2013 and see how military spending has changed over time for each country

MilitarySpending1 = pd.melt(frame=TenCountriesSpending2, id_vars='Country')

# Rename the columns
MilitarySpending1.columns = ['Country', 'Year', 'Military Spending']

MilitarySpending_2013 = MilitarySpending1.head(10)
print(MilitarySpending_2013)
# Out:
#               Country  Year  Military Spending
# 0       United States  2013   639704000000.000
# 1               China  2013   179880000000.000
# 2  Russian Federation  2013    88352896464.000
# 3             Germany  2013    45930540563.000
# 4      United Kingdom  2013    56861759588.000
# 5              France  2013    62417099178.000
# 6               Italy  2013    33891913925.000
# 7  Iran, Islamic Rep.  2013    11997186984.000
# 8              Israel  2013    17302223635.000
# 9        Saudi Arabia  2013    67020000000.000

# %%
MilitarySpending_2013['sum']=MilitarySpending_2013.iloc[0:9,2].sum()
MilitarySpending_2013
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#               Country  Year  Military Spending               sum
# 0       United States  2013   639704000000.000 1136337620337.000
# 1               China  2013   179880000000.000 1136337620337.000
# 2  Russian Federation  2013    88352896464.000 1136337620337.000
# 3             Germany  2013    45930540563.000 1136337620337.000
# 4      United Kingdom  2013    56861759588.000 1136337620337.000
# 5              France  2013    62417099178.000 1136337620337.000
# 6               Italy  2013    33891913925.000 1136337620337.000
# 7  Iran, Islamic Rep.  2013    11997186984.000 1136337620337.000
# ...

# %%
MilitarySpending_Porportionof2013 = MilitarySpending_2013['Military Spending']/MilitarySpending_2013['sum']
MilitarySpending_Porportionof2013.index=['United States','China','Russian Federation','Germany','United Kingdom','France','Italy','Iran, Islamic Rep.','Israel','Saudi Arabia']
MilitarySpending_Porportionof2013
# Out:
# United States        0.563
# China                0.158
# Russian Federation   0.078
# Germany              0.040
# United Kingdom       0.050
# France               0.055
# Italy                0.030
# Iran, Islamic Rep.   0.011
# Israel               0.015
# Saudi Arabia         0.059
# dtype: float64

# %%
#2) Compare the data to the overall military spending of the all 10 countries
MilitarySpending_Porportionof2013.plot(kind='bar',figsize = (15,10), title= "Percentage of Military Spending in 2013 by Ten Countries")
# in 2013, USA for example, spent over 50% of the total military spending for that year in comparison to other nine countries.

# %% [markdown]
# # 3 •	Compare the per person military spending to the per person GDP

# %% [markdown]
# ### Import GDP per Capita Data from the World Bank Org.

# %%
# Read Files using xlsx
excel_file = 'GDPPerCapitaWorldBank.xlsx'
GDP_Per_Capita_WorldBank = pd.read_excel(excel_file)
#GDP_Per_Capita_WorldBank = pd.read_excel(excel_file, skiprows=3)
GDP_Per_Capita_WorldBank.head(10)
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date          2018-09-21 00:00:00
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
# 5        Afghanistan                          AFG
# 6             Angola                          AGO
# 7            Albania                          ALB
# 8            Andorra                          AND
# 9         Arab World                          ARB
#
#                      Unnamed: 2      Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0                           NaN             NaN         nan         nan
# 1                           NaN             NaN         nan         nan
# 2                           NaN             NaN         nan         nan
# 3                Indicator Name  Indicator Code    1960.000    1961.000
# ...

# %%
# Remove GDP Columns 
GDP_Per_Capita_WorldBank.drop(GDP_Per_Capita_WorldBank.iloc[:,2:57], axis=1, inplace=True)
GDP_Per_Capita_WorldBank.head(10) # now our columns start from Country Code then 2013-2017 but we need to delete rows as well
# Out:
#          Data Source World Development Indicators  Unnamed: 57  Unnamed: 58  \
# 0                NaN                          NaN          nan          nan
# 1  Last Updated Date          2018-09-21 00:00:00          nan          nan
# 2                NaN                          NaN          nan          nan
# 3       Country Name                 Country Code     2013.000     2014.000
# 4              Aruba                          ABW          nan          nan
# 5        Afghanistan                          AFG      638.613      629.345
# 6             Angola                          AGO     4804.634     4707.578
# 7            Albania                          ALB     4413.082     4578.667
# 8            Andorra                          AND    40619.711    42294.995
# 9         Arab World                          ARB     7508.573     7452.815
#
#    Unnamed: 59  Unnamed: 60  Unnamed: 61
# 0          nan          nan          nan
# 1          nan          nan          nan
# ...

# %%
# Remove Rows in excel because of the header
GDP_Per_Capita_WorldBank.drop([0,1,2,3], axis=0, inplace=True)
GDP_Per_Capita_WorldBank.head()
# Out:
#    Data Source World Development Indicators  Unnamed: 57  Unnamed: 58  \
# 4        Aruba                          ABW          nan          nan
# 5  Afghanistan                          AFG      638.613      629.345
# 6       Angola                          AGO     4804.634     4707.578
# 7      Albania                          ALB     4413.082     4578.667
# 8      Andorra                          AND    40619.711    42294.995
#
#    Unnamed: 59  Unnamed: 60  Unnamed: 61
# 4          nan          nan          nan
# 5      569.578      561.779      585.850
# 6     3683.553     3308.773     4170.312
# 7     3952.831     4131.872     4537.862
# 8    36038.268    37231.816    39146.549

# %%
# replace column name
GDP_Per_Capita_WorldBank.columns=['Country Name','Country Code','2013','2014','2015','2016','2017']
#GDP_Per_Capita_WorldBank.head(5)

GDP_Per_Capita_WorldBank.drop(['Country Code'], axis=1, inplace=True) # drop country code

#Rename existing data column Country Name to Country
GDP_Per_Capita_WorldBank.rename(columns={'Country Name': 'Country'}, inplace=True)
GDP_Per_Capita_WorldBank.head(10)
# Out:
#                  Country      2013      2014      2015      2016      2017
# 4                  Aruba       nan       nan       nan       nan       nan
# 5            Afghanistan   638.613   629.345   569.578   561.779   585.850
# 6                 Angola  4804.634  4707.578  3683.553  3308.773  4170.312
# 7                Albania  4413.082  4578.667  3952.831  4131.872  4537.862
# 8                Andorra 40619.711 42294.995 36038.268 37231.816 39146.549
# 9             Arab World  7508.573  7452.815  6413.377  6151.181  6251.142
# 10  United Arab Emirates 43315.141 44443.062 39122.050 38517.800 40698.849
# 11             Argentina 12976.636 12245.256 13698.293 12654.355 14401.975
# 12               Armenia  3843.591  3994.712  3617.936  3605.743  3936.798
# 13        American Samoa 11589.853 11598.752 11865.963 11834.745       nan

# %%
######## 
pd.set_option('display.float_format', lambda x: '%.3f' % x)
GDP_Per_Capita_WorldBank.head()
# Out:
#        Country      2013      2014      2015      2016      2017
# 4        Aruba       nan       nan       nan       nan       nan
# 5  Afghanistan   638.613   629.345   569.578   561.779   585.850
# 6       Angola  4804.634  4707.578  3683.553  3308.773  4170.312
# 7      Albania  4413.082  4578.667  3952.831  4131.872  4537.862
# 8      Andorra 40619.711 42294.995 36038.268 37231.816 39146.549

# %%
GDP_Per_Capita_WorldBank_TenCountries=GDP_Per_Capita_WorldBank.set_index("Country", inplace=True) # set the index of data frame to country
GDP_Per_Capita_WorldBank_TenCountries

# %%
## Select Top 10 Countries for GDP
GDP_Per_Capita_WorldBank_TenCountries = GDP_Per_Capita_WorldBank.loc[['United States', 'China', 'Russian Federation', 'Germany', 'United Kingdom', 'France', 'Italy', 'Iran, Islamic Rep.', 'Israel','Saudi Arabia']]
GDP_TenCountries.head(10)
# Out:
#               Country               2013               2014  \
# 0       United States 16691500000000.000 17427600000000.000
# 1               China  9607220000000.000 10482400000000.000
# 2  Russian Federation  2297130000000.000  2063660000000.000
# 3             Germany  3752510000000.000  3890610000000.000
# 4      United Kingdom  2739820000000.000  3022830000000.000
# 5              France  2811080000000.000  2852170000000.000
# 6               Italy  2130490000000.000  2151730000000.000
# 7  Iran, Islamic Rep.   467415000000.000   434475000000.000
# 8              Israel   292489000000.000   308417000000.000
# 9        Saudi Arabia   746647000000.000   756350000000.000
#
#                 2015               2016               2017
# 0 18120700000000.000 18624500000000.000 19390600000000.000
# 1 11064700000000.000 11191000000000.000 12237700000000.000
# 2  1368400000000.000  1284730000000.000  1577520000000.000
# 3  3375610000000.000  3477800000000.000  3677440000000.000
# ...

# %%
GDP_Per_Capita_WorldBank_TenCountries.T
# Out:
# Country  United States    China  Russian Federation   Germany  United Kingdom  \
# 2013         52782.087 7077.771           16007.090 46530.911       42724.068
# 2014         54696.726 7683.503           14125.909 48042.563       46783.469
# 2015         56443.817 8069.213            9329.291 41323.922       44305.555
# 2016         57588.538 8117.267            8748.369 42232.574       40412.034
# 2017         59531.662 8826.994           10743.097 44469.909       39720.443
#
# Country    France     Italy  Iran, Islamic Rep.    Israel  Saudi Arabia
# 2013    42592.952 35370.275            6036.192 36291.232     24934.386
# 2014    43008.653 35396.666            5540.984 37539.952     24575.403
# 2015    36613.375 30180.322            4862.300 35690.963     20732.862
# 2016    36870.219 30668.981            5219.110 37180.850     19982.086
# 2017    38476.659 31952.976            5415.210 40270.251     20760.906

# %%
GDP_TenCountriesTransposed = GDP_Per_Capita_WorldBank_TenCountries.transpose()
GDP_TenCountriesTransposed.head()
# Out:
# Country  United States    China  Russian Federation   Germany  United Kingdom  \
# 2013         52782.087 7077.771           16007.090 46530.911       42724.068
# 2014         54696.726 7683.503           14125.909 48042.563       46783.469
# 2015         56443.817 8069.213            9329.291 41323.922       44305.555
# 2016         57588.538 8117.267            8748.369 42232.574       40412.034
# 2017         59531.662 8826.994           10743.097 44469.909       39720.443
#
# Country    France     Italy  Iran, Islamic Rep.    Israel  Saudi Arabia
# 2013    42592.952 35370.275            6036.192 36291.232     24934.386
# 2014    43008.653 35396.666            5540.984 37539.952     24575.403
# 2015    36613.375 30180.322            4862.300 35690.963     20732.862
# 2016    36870.219 30668.981            5219.110 37180.850     19982.086
# 2017    38476.659 31952.976            5415.210 40270.251     20760.906

# %%
#GDP_TenCountriesTransposed.head(10).to_csv('GDPPerCapitaCountriesFile.csv') # save to file the clean version

# %%
#3) Compare the per person military spending to the per person GDP. the per 
GDP_TenCountriesTransposed.plot(kind = 'bar',figsize=(16,10),fontsize = 10)
plt.ticklabel_format(style='plain',axis='y')
# the gross domestic product or production per person. ex. china in 2013, gdp per person is the second lowest to iran

# %%
#3) does military spending per person depend on gdp per capita? yes
#GDP_TenCountriesTransposed.corr()
correl = GDP_TenCountriesTransposed.corr(method='pearson')
correl.head(10)
# Out:
# Country             United States  China  Russian Federation  Germany  \
# Country
# United States               1.000  0.985              -0.802   -0.555
# China                       0.985  1.000              -0.746   -0.483
# Russian Federation         -0.802 -0.746               1.000    0.888
# Germany                    -0.555 -0.483               0.888    1.000
# United Kingdom             -0.631 -0.529               0.434    0.450
# France                     -0.735 -0.671               0.962    0.971
# Italy                      -0.729 -0.672               0.967    0.969
# Iran, Islamic Rep.         -0.606 -0.609               0.896    0.801
# Israel                      0.677  0.709              -0.112    0.205
# Saudi Arabia               -0.862 -0.798               0.974    0.889
#
# Country             United Kingdom  France  Italy  Iran, Islamic Rep.  Israel  \
# Country
# United States               -0.631  -0.735 -0.729              -0.606   0.677
# ...

# %% [markdown]
# ### Import Population Data from the World Bank Org.

# %%
# Read Files using xlsx
excel_file = 'Population1.xlsx'
Population_WorldBank = pd.read_excel(excel_file)
#GDP_Per_Capita_WorldBank = pd.read_excel(excel_file, skiprows=3)
Population_WorldBank.head(10)
# Out:
#          Data Source World Development Indicators         Unnamed: 2  \
# 0                NaN                          NaN                NaN
# 1  Last Updated Date          2018-09-21 00:00:00                NaN
# 2                NaN                          NaN                NaN
# 3       Country Name                 Country Code     Indicator Name
# 4              Aruba                          ABW  Population, total
# 5        Afghanistan                          AFG  Population, total
# 6             Angola                          AGO  Population, total
# 7            Albania                          ALB  Population, total
# 8            Andorra                          AND  Population, total
# 9         Arab World                          ARB  Population, total
#
#        Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6   Unnamed: 7  \
# 0             NaN         NaN         NaN         NaN          NaN
# 1             NaN         NaN         NaN         NaN          NaN
# ...

# %%
# Remove GDP Columns 
Population_WorldBank.drop(Population_WorldBank.iloc[:,2:57], axis=1, inplace=True)
Population_WorldBank.head(10) # now our columns start from Country Code then 2013-2017 but we need to delete rows as well
# Out:
#          Data Source World Development Indicators  Unnamed: 57  Unnamed: 58  \
# 0                NaN                          NaN          NaN          NaN
# 1  Last Updated Date          2018-09-21 00:00:00          NaN          NaN
# 2                NaN                          NaN          NaN          NaN
# 3       Country Name                 Country Code       2013.0       2014.0
# 4              Aruba                          ABW     103187.0     103795.0
# 5        Afghanistan                          AFG   31731688.0   32758020.0
# 6             Angola                          AGO   25998340.0   26920466.0
# 7            Albania                          ALB    2895092.0    2889104.0
# 8            Andorra                          AND      80788.0      79223.0
# 9         Arab World                          ARB  381702086.0  390043028.0
#
#    Unnamed: 59  Unnamed: 60  Unnamed: 61
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# ...

# %%
# Remove Rows in excel because of the header
Population_WorldBank.drop([0,1,2,3], axis=0, inplace=True)
Population_WorldBank.head()
# Out:
#    Data Source World Development Indicators  Unnamed: 57  Unnamed: 58  \
# 4        Aruba                          ABW     103187.0     103795.0
# 5  Afghanistan                          AFG   31731688.0   32758020.0
# 6       Angola                          AGO   25998340.0   26920466.0
# 7      Albania                          ALB    2895092.0    2889104.0
# 8      Andorra                          AND      80788.0      79223.0
#
#    Unnamed: 59  Unnamed: 60  Unnamed: 61
# 4     104341.0     104822.0     105264.0
# 5   33736494.0   34656032.0   35530081.0
# 6   27859305.0   28813463.0   29784193.0
# 7    2880703.0    2876101.0    2873457.0
# 8      78014.0      77281.0      76965.0

# %%
# replace column name
Population_WorldBank.columns=['Country Name','Country Code','2013','2014','2015','2016','2017']
#GDP_Per_Capita_WorldBank.head(5)

Population_WorldBank.drop(['Country Code'], axis=1, inplace=True) # drop country code

#Rename existing data column Country Name to Country
Population_WorldBank.rename(columns={'Country Name': 'Country'}, inplace=True)
Population_WorldBank.head(10)
# Out:
#                  Country         2013         2014         2015         2016  \
# 4                  Aruba     103187.0     103795.0     104341.0     104822.0
# 5            Afghanistan   31731688.0   32758020.0   33736494.0   34656032.0
# 6                 Angola   25998340.0   26920466.0   27859305.0   28813463.0
# 7                Albania    2895092.0    2889104.0    2880703.0    2876101.0
# 8                Andorra      80788.0      79223.0      78014.0      77281.0
# 9             Arab World  381702086.0  390043028.0  398304960.0  406452690.0
# 10  United Arab Emirates    9006263.0    9070867.0    9154302.0    9269612.0
# 11             Argentina   42539925.0   42981515.0   43417765.0   43847430.0
# 12               Armenia    2893509.0    2906220.0    2916950.0    2924816.0
# 13        American Samoa      55307.0      55437.0      55537.0      55599.0
#
#            2017
# 4      105264.0
# 5    35530081.0
# 6    29784193.0
# 7     2873457.0
# 8       76965.0
# 9   414491886.0
# ...

# %%
####
pd.set_option('display.float_format', lambda x: '%.3f' % x)
Population_WorldBank.head()
# Out:
#        Country         2013         2014         2015         2016  \
# 4        Aruba   103187.000   103795.000   104341.000   104822.000
# 5  Afghanistan 31731688.000 32758020.000 33736494.000 34656032.000
# 6       Angola 25998340.000 26920466.000 27859305.000 28813463.000
# 7      Albania  2895092.000  2889104.000  2880703.000  2876101.000
# 8      Andorra    80788.000    79223.000    78014.000    77281.000
#
#           2017
# 4   105264.000
# 5 35530081.000
# 6 29784193.000
# 7  2873457.000
# 8    76965.000

# %%
Population_WorldBank_TenCountries=Population_WorldBank.set_index("Country", inplace=True) # set the index of data frame to country
Population_WorldBank_TenCountries

# %%
## Select Top 10 Countries for Population
Population_WorldBank_TenCountries = Population_WorldBank.loc[['United States', 'China', 'Russian Federation', 'Germany', 'United Kingdom', 'France', 'Italy', 'Iran, Islamic Rep.', 'Israel','Saudi Arabia']]
Population_WorldBank_TenCountries.head(10)
# Out:
#                              2013           2014           2015  \
# Country
# United States       316234505.000  318622525.000  321039839.000
# China              1357380000.000 1364270000.000 1371220000.000
# Russian Federation  143506911.000  143819666.000  144096870.000
# Germany              80645605.000   80982500.000   81686611.000
# United Kingdom       64128226.000   64613160.000   65128861.000
# France               65998660.000   66316092.000   66593366.000
# Italy                60233948.000   60789140.000   60730582.000
# Iran, Islamic Rep.   77435384.000   78411092.000   79360487.000
# Israel                8059500.000    8215700.000    8380100.000
# Saudi Arabia         29944476.000   30776722.000   31557144.000
#
#                              2016           2017
# Country
# United States       323405935.000  325719178.000
# China              1378665000.000 1386395000.000
# Russian Federation  144342396.000  144495044.000
# ...

# %%
Population_WorldBank_TenCountriesTransposed=Population_WorldBank_TenCountries.T
Population_WorldBank_TenCountriesTransposed
# Out:
# Country  United States          China  Russian Federation      Germany  \
# 2013     316234505.000 1357380000.000       143506911.000 80645605.000
# 2014     318622525.000 1364270000.000       143819666.000 80982500.000
# 2015     321039839.000 1371220000.000       144096870.000 81686611.000
# 2016     323405935.000 1378665000.000       144342396.000 82348669.000
# 2017     325719178.000 1386395000.000       144495044.000 82695000.000
#
# Country  United Kingdom       France        Italy  Iran, Islamic Rep.  \
# 2013       64128226.000 65998660.000 60233948.000        77435384.000
# 2014       64613160.000 66316092.000 60789140.000        78411092.000
# 2015       65128861.000 66593366.000 60730582.000        79360487.000
# 2016       65595565.000 66859768.000 60627498.000        80277428.000
# 2017       66022273.000 67118648.000 60551416.000        81162788.000
#
# Country      Israel  Saudi Arabia
# 2013    8059500.000  29944476.000
# 2014    8215700.000  30776722.000
# ...

# %%
MilitaryPerPerson_Spending = MilitarySpending/Population_WorldBank_TenCountriesTransposed
MilitaryPerPerson_Spending
# Out:
#      United States   China Russian Federation Germany United Kingdom  France  \
# 2013      2022.879 132.520            615.670 569.536        886.688 945.733
# 2014      1914.221 147.164            588.908 569.292        915.957 959.248
# 2015      1856.794 156.133            460.931 487.382        827.009 831.046
# 2016      1855.581 156.696            479.730 504.920        733.570 857.891
# 2017      1872.036 164.622            459.081 536.058        714.806 860.716
#
#        Italy Iran, Islamic Rep.   Israel Saudi Arabia
# 2013 562.671            154.932 2146.811     2238.142
# 2014 519.376            126.272 2249.487     2624.139
# 2015 416.506            133.426 2024.228     2762.793
# 2016 465.232            152.770 1729.790     1972.779
# 2017 482.836            179.245 1892.593     2107.380

# %%
MilitaryPerPerson_Spending.plot(kind = 'bar',figsize=(10,8),fontsize = 10)
plt.ticklabel_format(style='plain',axis='y')
# how much each country spends per person (military exp.)

# %%
Ratio_per= MilitaryPerPerson_Spending/GDP_TenCountriesTransposed
Ratio_per
# Out:
#      United States China Russian Federation Germany United Kingdom France  \
# 2013         0.038 0.019              0.038   0.012          0.021  0.022
# 2014         0.035 0.019              0.042   0.012          0.020  0.022
# 2015         0.033 0.019              0.049   0.012          0.019  0.023
# 2016         0.032 0.019              0.055   0.012          0.018  0.023
# 2017         0.031 0.019              0.043   0.012          0.018  0.022
#
#      Italy Iran, Islamic Rep. Israel Saudi Arabia
# 2013 0.016              0.026  0.059        0.090
# 2014 0.015              0.023  0.060        0.107
# 2015 0.014              0.027  0.057        0.133
# 2016 0.015              0.029  0.047        0.099
# 2017 0.015              0.033  0.047        0.102

# %%
#4) Compare the per person military spending to the per person GDP. the per 
Ratio_per.plot(kind = 'bar',figsize=(16,10),fontsize = 10)
plt.ticklabel_format(style='plain',axis='y')
# in the past 5 years  Saudi arabia has had the highest percentage, followed by isreal as the second highest for the ratio of military per person and gdp per person
# comparing  this data to 2013, in 2017, suprisingly china's percentage has remained the same.
# although saudi has one of the lowest GDP per person percentage, it has maintained it's investment in military spending person
# the ratio has beeen going up for saudi arabia and the trend has been the more or less the same for the other countries

# %%
#•	Single out the fastest growing countries in military spending in fixed value and in percentage
# we can calculate the rate of change by the following formula: 
#militry spending2017- military spending2016/militaryspending2016

#United States: from 2016 to 2017, US has positively increased by 0.016083825190882944 or 1.6%
(609758000000-600106000000)/600106000000
# Out:
# 0.016083825190882944

# %%
#China : from 2016 to 2017, US has positively increased by 0.05647337650614958 or 5.6%
(228231000000-216031000000)/216031000000
# Out:
# 0.05647337650614958
